# %% [markdown]
# # Context: The data is from a search platform that the end customers use as a capability within their products.
#
# ##Data: Attached file contains Query performance, Product performance, and product description of a sample set from one of the search product customers.
#
# ##Objective: To increase conversions for customers.
#
# ##Question: What would you do keeping in mind that the customer uses this search product? How can you use this data to bring out insights to improve the search product?

# %%
# Install DATAPREP library of Python which is great library for Data Cleaning and Data Visualizatio

# %%
# !pip install dataprep
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached dataprep-0.4.5-py3-none-any.whl (9.9 MB)
# ...
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: "C:\\Users\\Bellary's\\AppData\\Roaming\\Python\\Python39\\site-packages\\dataprep\\eda\\dtypes.py"
# Check the permissions.
# ...

# %%
import pandas as pd
df=pd.read_excel('Customer_data1.xlsx')
df1=pd.read_excel('Customer_data1.xlsx',sheet_name=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df3=pd.merge(df,df1,left_on='PID',right_on='pId',how='inner')
df3
# Out:
#            PID                                   Product Name Category  \
# 0    CL0036386            Ikat stripe print cotton knit dress    Dress
# 1    CL0030567                    Feminine pleated knit dress    Dress
# 2    CL0032320   Floral embellished chambray denim maxi dress    Dress
# 3    CL0036700                     Dot print cap sleeve shirt      Top
# 4    CL0036365          Layered asymmetric hem hacci knit top      Top
# ..         ...                                            ...      ...
# 711  CL0031288                      Ruffle front poplin dress    Dress
# 712  CL0032199              Beaded cotton poplin sheath dress    Dress
# 713  CL0031267          Embellished stripe waist poplin dress    Dress
# 714  CL0031287                        Sash waist poplin skirt    Skirt
# 715  CL0031947                  Colorblock retro poplin frock    Dress
#
#                    Color        Primary Color           Fabric        pId  \
# ...

# %%
pip install pandas-profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(df3)
profile.to_file("Customer_data.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df.describe([.25,.75])
# Out:
#               PID                           Product Name Category   Color  \
# count         716                                    716      716     716
# unique        716                                    646        6     327
# top     CL0036386   Chevron stripe colorblock maxi dress    Dress   Black
# freq            1                                      7      428      39
#
#        Primary Color   Fabric
# count            716      716
# unique           122       26
# top            Black   Cotton
# freq             100      263
